# %% [markdown]
# Generate Random Geographic Coordinates and a List of Cities

# %%
#!pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import seaborn as sns
import datetime as datetime
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 653

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Setting the URL as an fstring in loop.
#url = f'https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}''
#https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}
#https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = (f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric')
    
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url).json()
        #time.sleep(1)
        city_weather = response['weather']

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response['coord']['lat']
        city_lng = response['coord']['lon']
        city_max_temp = response['main']['temp_max']
        city_humidity = response['main']['humidity']
        city_clouds = response['clouds']['all']
        city_wind = response['wind']['speed']
        city_country = response['sys']['country']
        city_date = response['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        print(city_url)
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | bonavista
# Processing Record 3 of Set 1 | mamedkala
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | calabozo
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | ilulissat
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | antalaha
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | nemuro
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | naliya
# Processing Record 15 of Set 1 | sao raimundo nonato
# Processing Record 16 of Set 1 | campohermoso
# Processing Record 17 of Set 1 | asau
# Processing Record 18 of Set 1 | krasnyy oktyabr
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=taolanaro&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 21 of Set 1 | darhan
# Processing Record 22 of Set 1 | halalo
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=halalo&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 23 of Set 1 | lasa
# Processing Record 24 of Set 1 | ostrovnoy
# Processing Record 25 of Set 1 | teya
# Processing Record 26 of Set 1 | yulara
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | kieta
# Processing Record 30 of Set 1 | isla mujeres
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | odienne
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | amderma
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=amderma&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 35 of Set 1 | alofi
# Processing Record 36 of Set 1 | bandarbeyla
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | palabuhanratu
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=palabuhanratu&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 39 of Set 1 | gweta
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | vallenar
# Processing Record 43 of Set 1 | warqla
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=warqla&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 44 of Set 1 | marawi
# Processing Record 45 of Set 1 | ipixuna
# Processing Record 46 of Set 1 | waingapu
# Processing Record 47 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=ust-kamchatsk&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 48 of Set 1 | kaeo
# Processing Record 49 of Set 1 | sisimiut
# Processing Record 50 of Set 1 | marzuq
# Processing Record 0 of Set 2 | punta arenas
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | westport
# Processing Record 3 of Set 2 | verkhoyansk
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=barentsburg&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 5 of Set 2 | constitucion
# Processing Record 6 of Set 2 | longyearbyen
# Processing Record 7 of Set 2 | jalu
# Processing Record 8 of Set 2 | senneterre
# Processing Record 9 of Set 2 | fortuna
# Processing Record 10 of Set 2 | labutta
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=labutta&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | bocana de paiwas
# Processing Record 13 of Set 2 | palivere
# Processing Record 14 of Set 2 | lima
# Processing Record 15 of Set 2 | pringsewu
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | ancud
# Processing Record 18 of Set 2 | okha
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | nur
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | qasigiannguit
# Processing Record 24 of Set 2 | senanga
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | grindavik
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 30 of Set 2 | najran
# Processing Record 31 of Set 2 | victoria
# Processing Record 32 of Set 2 | rocha
# Processing Record 33 of Set 2 | llangefni
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | ushuaia
# Processing Record 37 of Set 2 | busselton
# Processing Record 38 of Set 2 | nome
# Processing Record 39 of Set 2 | lerwick
# Processing Record 40 of Set 2 | olden
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | mitsamiouli
# Processing Record 43 of Set 2 | ayan
# Processing Record 44 of Set 2 | saint george
# Processing Record 45 of Set 2 | codrington
# Processing Record 46 of Set 2 | dzhusaly
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=dzhusaly&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 47 of Set 2 | clyde river
# Processing Record 48 of Set 2 | sinnamary
# Processing Record 49 of Set 2 | shatrovo
# Processing Record 0 of Set 3 | queanbeyan
# Processing Record 1 of Set 3 | lebu
# Processing Record 2 of Set 3 | saskylakh
# Processing Record 3 of Set 3 | isangel
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | saint andrews
# Processing Record 6 of Set 3 | carauari
# Processing Record 7 of Set 3 | rikitea
# Processing Record 8 of Set 3 | tallahassee
# Processing Record 9 of Set 3 | rafai
# Processing Record 10 of Set 3 | pangody
# Processing Record 11 of Set 3 | mehamn
# Processing Record 12 of Set 3 | ironton
# Processing Record 13 of Set 3 | hobart
# Processing Record 14 of Set 3 | belushya guba
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=belushya guba&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 15 of Set 3 | provideniya
# Processing Record 16 of Set 3 | kalmunai
# Processing Record 17 of Set 3 | dondo
# Processing Record 18 of Set 3 | ahipara
# Processing Record 19 of Set 3 | dunmore east
# Processing Record 20 of Set 3 | collie
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | faanui
# Processing Record 23 of Set 3 | lompoc
# Processing Record 24 of Set 3 | saint-philippe
# Processing Record 25 of Set 3 | pangai
# Processing Record 26 of Set 3 | gradinari
# Processing Record 27 of Set 3 | disna
# Processing Record 28 of Set 3 | severnoye
# Processing Record 29 of Set 3 | mys shmidta
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=mys shmidta&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 30 of Set 3 | serenje
# Processing Record 31 of Set 3 | kruisfontein
# Processing Record 32 of Set 3 | talnakh
# Processing Record 33 of Set 3 | warrington
# Processing Record 34 of Set 3 | san carlos de bariloche
# Processing Record 35 of Set 3 | husavik
# Processing Record 36 of Set 3 | la uribe
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=la uribe&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 37 of Set 3 | phuket
# Processing Record 38 of Set 3 | upington
# Processing Record 39 of Set 3 | torbay
# Processing Record 40 of Set 3 | isiro
# Processing Record 41 of Set 3 | stoyba
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=stoyba&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 42 of Set 3 | nizhneyansk
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 43 of Set 3 | bentiu
# Processing Record 44 of Set 3 | port blair
# Processing Record 45 of Set 3 | maumere
# Processing Record 46 of Set 3 | miandrivazo
# Processing Record 47 of Set 3 | komsomolskiy
# Processing Record 48 of Set 3 | hermanus
# Processing Record 49 of Set 3 | pisco
# Processing Record 0 of Set 4 | hilo
# Processing Record 1 of Set 4 | aksu
# Processing Record 2 of Set 4 | tuatapere
# Processing Record 3 of Set 4 | trofors
# Processing Record 4 of Set 4 | kurumkan
# Processing Record 5 of Set 4 | robertsport
# Processing Record 6 of Set 4 | gazojak
# Processing Record 7 of Set 4 | shevchenkove
# Processing Record 8 of Set 4 | castro
# Processing Record 9 of Set 4 | dikson
# Processing Record 10 of Set 4 | wewak
# Processing Record 11 of Set 4 | kodiak
# Processing Record 12 of Set 4 | kediri
# Processing Record 13 of Set 4 | nattam
# Processing Record 14 of Set 4 | sa kaeo
# Processing Record 15 of Set 4 | vanimo
# Processing Record 16 of Set 4 | lukow
# Processing Record 17 of Set 4 | shache
# Processing Record 18 of Set 4 | havoysund
# Processing Record 19 of Set 4 | karratha
# Processing Record 20 of Set 4 | caravelas
# Processing Record 21 of Set 4 | tsihombe
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=tsihombe&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 22 of Set 4 | ulladulla
# Processing Record 23 of Set 4 | umzimvubu
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=umzimvubu&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 24 of Set 4 | paoua
# Processing Record 25 of Set 4 | mold
# Processing Record 26 of Set 4 | tasiilaq
# Processing Record 27 of Set 4 | san jose
# Processing Record 28 of Set 4 | benguela
# Processing Record 29 of Set 4 | suoyarvi
# Processing Record 30 of Set 4 | qaanaaq
# Processing Record 31 of Set 4 | slave lake
# Processing Record 32 of Set 4 | jasper
# Processing Record 33 of Set 4 | sitka
# Processing Record 34 of Set 4 | sao gabriel da cachoeira
# Processing Record 35 of Set 4 | geraldton
# Processing Record 36 of Set 4 | oranjestad
# Processing Record 37 of Set 4 | acapulco
# Processing Record 38 of Set 4 | babanusah
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=babanusah&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 39 of Set 4 | marsa matruh
# Processing Record 40 of Set 4 | neiafu
# Processing Record 41 of Set 4 | narsaq
# Processing Record 42 of Set 4 | talcahuano
# Processing Record 43 of Set 4 | corinto
# Processing Record 44 of Set 4 | alta floresta
# Processing Record 45 of Set 4 | kahului
# Processing Record 46 of Set 4 | villa maria
# Processing Record 47 of Set 4 | marcona
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=marcona&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 48 of Set 4 | kaitangata
# Processing Record 49 of Set 4 | wazzan
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=wazzan&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 0 of Set 5 | sentyabrskiy
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 1 of Set 5 | batagay
# Processing Record 2 of Set 5 | cabanglasan
# Processing Record 3 of Set 5 | kilmallock
# Processing Record 4 of Set 5 | zyryanovsk
# Processing Record 5 of Set 5 | nakatsu
# Processing Record 6 of Set 5 | severo-kurilsk
# Processing Record 7 of Set 5 | carnarvon
# Processing Record 8 of Set 5 | port hedland
# Processing Record 9 of Set 5 | vukovar
# Processing Record 10 of Set 5 | sangueya
# Processing Record 11 of Set 5 | kloulklubed
# Processing Record 12 of Set 5 | namibe
# Processing Record 13 of Set 5 | pa sang
# Processing Record 14 of Set 5 | mbanza-ngungu
# Processing Record 15 of Set 5 | gouyave
# Processing Record 16 of Set 5 | touros
# Processing Record 17 of Set 5 | kumba
# Processing Record 18 of Set 5 | attawapiskat
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=attawapiskat&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 19 of Set 5 | moerai
# Processing Record 20 of Set 5 | sistranda
# Processing Record 21 of Set 5 | korla
# Processing Record 22 of Set 5 | san patricio
# Processing Record 23 of Set 5 | mogadishu
# Processing Record 24 of Set 5 | karamea
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=karamea&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 25 of Set 5 | chagda
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=chagda&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 26 of Set 5 | saint-joseph
# Processing Record 27 of Set 5 | airai
# Processing Record 28 of Set 5 | oistins
# Processing Record 29 of Set 5 | natal
# Processing Record 30 of Set 5 | lagoa
# Processing Record 31 of Set 5 | saryagash
# Processing Record 32 of Set 5 | te anau
# Processing Record 33 of Set 5 | wulanhaote
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=wulanhaote&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 34 of Set 5 | byron bay
# Processing Record 35 of Set 5 | takab
# Processing Record 36 of Set 5 | xam nua
# Processing Record 37 of Set 5 | goderich
# Processing Record 38 of Set 5 | fairbanks
# Processing Record 39 of Set 5 | broome
# Processing Record 40 of Set 5 | yambio
# Processing Record 41 of Set 5 | pascagoula
# Processing Record 42 of Set 5 | arraial do cabo
# Processing Record 43 of Set 5 | wicklow
# Processing Record 44 of Set 5 | bengkulu
# Processing Record 45 of Set 5 | kefar weradim
# Processing Record 46 of Set 5 | turukhansk
# Processing Record 47 of Set 5 | jinchengjiang
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=jinchengjiang&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 48 of Set 5 | noyabrsk
# Processing Record 49 of Set 5 | laguna
# Processing Record 0 of Set 6 | verkhnyaya inta
# Processing Record 1 of Set 6 | grenville
# Processing Record 2 of Set 6 | mocuba
# Processing Record 3 of Set 6 | wajima
# Processing Record 4 of Set 6 | zhangjiakou
# Processing Record 5 of Set 6 | merrill
# Processing Record 6 of Set 6 | butembo
# Processing Record 7 of Set 6 | la ronge
# Processing Record 8 of Set 6 | san isidro
# Processing Record 9 of Set 6 | inhambane
# Processing Record 10 of Set 6 | komsomolets
# Processing Record 11 of Set 6 | bredasdorp
# Processing Record 12 of Set 6 | nhulunbuy
# Processing Record 13 of Set 6 | broken hill
# Processing Record 14 of Set 6 | champerico
# Processing Record 15 of Set 6 | khatanga
# Processing Record 16 of Set 6 | vartholomio
# Processing Record 17 of Set 6 | uddevalla
# Processing Record 18 of Set 6 | am timan
# Processing Record 19 of Set 6 | bocaranga
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=bocaranga&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 20 of Set 6 | nishinomiya
# Processing Record 21 of Set 6 | vardo
# Processing Record 22 of Set 6 | krasnyy chikoy
# Processing Record 23 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 6 | ornskoldsvik
# Processing Record 25 of Set 6 | klaksvik
# Processing Record 26 of Set 6 | deputatskiy
# Processing Record 27 of Set 6 | houma
# Processing Record 28 of Set 6 | tupelo
# Processing Record 29 of Set 6 | riyadh
# Processing Record 30 of Set 6 | leningradskiy
# Processing Record 31 of Set 6 | san cristobal
# Processing Record 32 of Set 6 | baykit
# Processing Record 33 of Set 6 | palanga
# Processing Record 34 of Set 6 | saleaula
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=saleaula&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 35 of Set 6 | chatsu
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=chatsu&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 36 of Set 6 | arvika
# Processing Record 37 of Set 6 | polyarnyy
# Processing Record 38 of Set 6 | kashi
# Processing Record 39 of Set 6 | tilichiki
# Processing Record 40 of Set 6 | manacapuru
# Processing Record 41 of Set 6 | grand river south east
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=grand river south east&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 42 of Set 6 | bambous virieux
# Processing Record 43 of Set 6 | boralday
# Processing Record 44 of Set 6 | chokurdakh
# Processing Record 45 of Set 6 | chiredzi
# Processing Record 46 of Set 6 | sioux lookout
# Processing Record 47 of Set 6 | seoul
# Processing Record 48 of Set 6 | mama
# Processing Record 49 of Set 6 | mayo
# Processing Record 0 of Set 7 | hidrolandia
# Processing Record 1 of Set 7 | flic en flac
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | coquimbo
# Processing Record 4 of Set 7 | sfantu gheorghe
# Processing Record 5 of Set 7 | seydisehir
# Processing Record 6 of Set 7 | labuhan
# Processing Record 7 of Set 7 | necochea
# Processing Record 8 of Set 7 | songea
# Processing Record 9 of Set 7 | storforshei
# Processing Record 10 of Set 7 | chuy
# Processing Record 11 of Set 7 | louisbourg
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=louisbourg&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 12 of Set 7 | satitoa
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=satitoa&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 13 of Set 7 | genhe
# Processing Record 14 of Set 7 | akcakoca
# Processing Record 15 of Set 7 | shingu
# Processing Record 16 of Set 7 | norman wells
# Processing Record 17 of Set 7 | muroto
# Processing Record 18 of Set 7 | hudson bay
# Processing Record 19 of Set 7 | trairi
# Processing Record 20 of Set 7 | sur
# Processing Record 21 of Set 7 | chegutu
# Processing Record 22 of Set 7 | florianopolis
# Processing Record 23 of Set 7 | olinda
# Processing Record 24 of Set 7 | elliot lake
# Processing Record 25 of Set 7 | saldanha
# Processing Record 26 of Set 7 | brejo
# Processing Record 27 of Set 7 | nalut
# Processing Record 28 of Set 7 | madera
# Processing Record 29 of Set 7 | dutlwe
# Processing Record 30 of Set 7 | nantucket
# Processing Record 31 of Set 7 | simoes
# Processing Record 32 of Set 7 | aqtobe
# Processing Record 33 of Set 7 | bereda
# Processing Record 34 of Set 7 | mao
# Processing Record 35 of Set 7 | pihuamo
# Processing Record 36 of Set 7 | along
# Processing Record 37 of Set 7 | vieira de leiria
# Processing Record 38 of Set 7 | shieli
# Processing Record 39 of Set 7 | teknaf
# Processing Record 40 of Set 7 | poum
# Processing Record 41 of Set 7 | avera
# Processing Record 42 of Set 7 | new norfolk
# Processing Record 43 of Set 7 | abapo
# Processing Record 44 of Set 7 | garmisch-partenkirchen
# Processing Record 45 of Set 7 | chabahar
# Processing Record 46 of Set 7 | flinders
# Processing Record 47 of Set 7 | aulum
# Processing Record 48 of Set 7 | axim
# Processing Record 49 of Set 7 | flagstaff
# Processing Record 0 of Set 8 | hamilton
# Processing Record 1 of Set 8 | whithorn
# Processing Record 2 of Set 8 | medicine hat
# Processing Record 3 of Set 8 | saint-pierre
# Processing Record 4 of Set 8 | ormara
# Processing Record 5 of Set 8 | makung
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=makung&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 6 of Set 8 | armacao dos buzios
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=armacao dos buzios&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 7 of Set 8 | boca do acre
# Processing Record 8 of Set 8 | xining
# Processing Record 9 of Set 8 | yoichi
# Processing Record 10 of Set 8 | shashi
# Processing Record 11 of Set 8 | huainan
# Processing Record 12 of Set 8 | marrakesh
# Processing Record 13 of Set 8 | kaz
# Processing Record 14 of Set 8 | ledyard
# Processing Record 15 of Set 8 | soyo
# Processing Record 16 of Set 8 | hithadhoo
# Processing Record 17 of Set 8 | lake city
# Processing Record 18 of Set 8 | atbasar
# Processing Record 19 of Set 8 | yaan
# Processing Record 20 of Set 8 | linchuan
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=linchuan&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 21 of Set 8 | bosaso
# Processing Record 22 of Set 8 | basco
# Processing Record 23 of Set 8 | prince george
# Processing Record 24 of Set 8 | vila
# Processing Record 25 of Set 8 | samusu
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=samusu&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 26 of Set 8 | balkhash
# Processing Record 27 of Set 8 | maragogi
# Processing Record 28 of Set 8 | solano
# Processing Record 29 of Set 8 | cidreira
# Processing Record 30 of Set 8 | maneadero
# Processing Record 31 of Set 8 | dakar
# Processing Record 32 of Set 8 | el dorado
# Processing Record 33 of Set 8 | boyolangu
# Processing Record 34 of Set 8 | apodi
# Processing Record 35 of Set 8 | baijiantan
# Processing Record 36 of Set 8 | council bluffs
# Processing Record 37 of Set 8 | jining
# Processing Record 38 of Set 8 | lagunas
# Processing Record 39 of Set 8 | bonthe
# Processing Record 40 of Set 8 | sorvag
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=sorvag&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 41 of Set 8 | honiara
# Processing Record 42 of Set 8 | berbera
# Processing Record 43 of Set 8 | segou
# Processing Record 44 of Set 8 | iquique
# Processing Record 45 of Set 8 | hamadan
# Processing Record 46 of Set 8 | eydhafushi
# Processing Record 47 of Set 8 | sabzevar
# Processing Record 48 of Set 8 | saint-augustin
# Processing Record 49 of Set 8 | douglas
# Processing Record 0 of Set 9 | kuching
# Processing Record 1 of Set 9 | noumea
# Processing Record 2 of Set 9 | itoman
# Processing Record 3 of Set 9 | chapais
# Processing Record 4 of Set 9 | srednekolymsk
# Processing Record 5 of Set 9 | doka
# Processing Record 6 of Set 9 | haines junction
# Processing Record 7 of Set 9 | dingle
# Processing Record 8 of Set 9 | ichinoseki
# Processing Record 9 of Set 9 | polunochnoye
# Processing Record 10 of Set 9 | campeche
# Processing Record 11 of Set 9 | plettenberg bay
# Processing Record 12 of Set 9 | bullhead city
# Processing Record 13 of Set 9 | gisborne
# Processing Record 14 of Set 9 | vila velha
# Processing Record 15 of Set 9 | nago
# Processing Record 16 of Set 9 | beira
# Processing Record 17 of Set 9 | los llanos de aridane
# Processing Record 18 of Set 9 | abadiania
# Processing Record 19 of Set 9 | benito juarez
# Processing Record 20 of Set 9 | tiruvottiyur
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=tiruvottiyur&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 21 of Set 9 | burica
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=burica&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 22 of Set 9 | moscow
# Processing Record 23 of Set 9 | awjilah
# Processing Record 24 of Set 9 | thabazimbi
# Processing Record 25 of Set 9 | rancho palos verdes
# Processing Record 26 of Set 9 | nuuk
# Processing Record 27 of Set 9 | lavrentiya
# Processing Record 28 of Set 9 | condoto
# Processing Record 29 of Set 9 | samarai
# Processing Record 30 of Set 9 | sao filipe
# Processing Record 31 of Set 9 | kilmez
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=kilmez&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 32 of Set 9 | tonantins
# Processing Record 33 of Set 9 | idrinskoye
# Processing Record 34 of Set 9 | saryshagan
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=saryshagan&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 35 of Set 9 | lashio
# Processing Record 36 of Set 9 | rzhev
# Processing Record 37 of Set 9 | jinxi
# Processing Record 38 of Set 9 | cairns
# Processing Record 39 of Set 9 | cockburn town
# Processing Record 40 of Set 9 | cururupu
# Processing Record 41 of Set 9 | calatayud
# Processing Record 42 of Set 9 | whitehorse
# Processing Record 43 of Set 9 | mount pleasant
# Processing Record 44 of Set 9 | ixtapa
# Processing Record 45 of Set 9 | paamiut
# Processing Record 46 of Set 9 | ambon
# Processing Record 47 of Set 9 | banyo
# Processing Record 48 of Set 9 | farafangana
# Processing Record 49 of Set 9 | kyaikkami
# Processing Record 0 of Set 10 | lodwar
# Processing Record 1 of Set 10 | harindanga
# Processing Record 2 of Set 10 | sulangan
# Processing Record 3 of Set 10 | hirna
# Processing Record 4 of Set 10 | yerbogachen
# Processing Record 5 of Set 10 | veraval
# Processing Record 6 of Set 10 | urumqi
# Processing Record 7 of Set 10 | cayenne
# Processing Record 8 of Set 10 | antanifotsy
# Processing Record 9 of Set 10 | pitimbu
# Processing Record 10 of Set 10 | puro
# Processing Record 11 of Set 10 | hargeysa
# Processing Record 12 of Set 10 | port lincoln
# Processing Record 13 of Set 10 | izhma
# Processing Record 14 of Set 10 | kazalinsk
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=kazalinsk&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 15 of Set 10 | pemba
# Processing Record 16 of Set 10 | jacareacanga
# Processing Record 17 of Set 10 | beloha
# Processing Record 18 of Set 10 | pizarro
# Processing Record 19 of Set 10 | yarada
# Processing Record 20 of Set 10 | kavaratti
# Processing Record 21 of Set 10 | yangambi
# Processing Record 22 of Set 10 | misratah
# Processing Record 23 of Set 10 | novobirilyussy
# Processing Record 24 of Set 10 | helong
# Processing Record 25 of Set 10 | minsk
# Processing Record 26 of Set 10 | sungairaya
# Processing Record 27 of Set 10 | zemio
# Processing Record 28 of Set 10 | puerto madryn
# Processing Record 29 of Set 10 | marathon
# Processing Record 30 of Set 10 | buala
# Processing Record 31 of Set 10 | iberia
# Processing Record 32 of Set 10 | bonfim
# Processing Record 33 of Set 10 | pangkalanbuun
# Processing Record 34 of Set 10 | daule
# Processing Record 35 of Set 10 | lolua
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=lolua&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 36 of Set 10 | berlevag
# Processing Record 37 of Set 10 | waipawa
# Processing Record 38 of Set 10 | mattru
# Processing Record 39 of Set 10 | colac
# Processing Record 40 of Set 10 | katherine
# Processing Record 41 of Set 10 | mutoko
# Processing Record 42 of Set 10 | surab
# Processing Record 43 of Set 10 | tessalit
# Processing Record 44 of Set 10 | asyut
# Processing Record 45 of Set 10 | honningsvag
# Processing Record 46 of Set 10 | zyryanka
# Processing Record 47 of Set 10 | bustamante
# Processing Record 48 of Set 10 | ingham
# Processing Record 49 of Set 10 | north bend
# Processing Record 0 of Set 11 | san rafael
# Processing Record 1 of Set 11 | nayoro
# Processing Record 2 of Set 11 | iqaluit
# Processing Record 3 of Set 11 | waconia
# Processing Record 4 of Set 11 | samalaeulu
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=samalaeulu&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 5 of Set 11 | chaumont
# Processing Record 6 of Set 11 | oktyabrskiy
# Processing Record 7 of Set 11 | richards bay
# Processing Record 8 of Set 11 | saint stephen
# Processing Record 9 of Set 11 | ventspils
# Processing Record 10 of Set 11 | arzgir
# Processing Record 11 of Set 11 | omsukchan
# Processing Record 12 of Set 11 | parsabad
# Processing Record 13 of Set 11 | bathsheba
# Processing Record 14 of Set 11 | saryg-sep
# Processing Record 15 of Set 11 | methoni
# Processing Record 16 of Set 11 | ferrol
# Processing Record 17 of Set 11 | jiuquan
# Processing Record 18 of Set 11 | parrita
# Processing Record 19 of Set 11 | searcy
# Processing Record 20 of Set 11 | skibbereen
# Processing Record 21 of Set 11 | little current
# Processing Record 22 of Set 11 | gat
# Processing Record 23 of Set 11 | tumannyy
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=tumannyy&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 24 of Set 11 | amazar
# Processing Record 25 of Set 11 | raudeberg
# Processing Record 26 of Set 11 | itarema
# Processing Record 27 of Set 11 | luderitz
# Processing Record 28 of Set 11 | topolobampo
# Processing Record 29 of Set 11 | souillac
# Processing Record 30 of Set 11 | saint anthony
# Processing Record 31 of Set 11 | phalaborwa
# Processing Record 32 of Set 11 | usinsk
# Processing Record 33 of Set 11 | pinega
# Processing Record 34 of Set 11 | healdsburg
# Processing Record 35 of Set 11 | xixiang
# Processing Record 36 of Set 11 | morondava
# Processing Record 37 of Set 11 | nanortalik
# Processing Record 38 of Set 11 | chancay
# Processing Record 39 of Set 11 | roanoke rapids
# Processing Record 40 of Set 11 | sabaudia
# Processing Record 41 of Set 11 | black river
# Processing Record 42 of Set 11 | gao
# Processing Record 43 of Set 11 | oltedal
# Processing Record 44 of Set 11 | cascais
# Processing Record 45 of Set 11 | montes altos
# Processing Record 46 of Set 11 | sao joao da barra
# Processing Record 47 of Set 11 | ust-omchug
# Processing Record 48 of Set 11 | miri
# Processing Record 49 of Set 11 | rolim de moura
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=rolim de moura&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 0 of Set 12 | hanover
# Processing Record 1 of Set 12 | fukue
# Processing Record 2 of Set 12 | madras
# Processing Record 3 of Set 12 | kayanza
# Processing Record 4 of Set 12 | cabo san lucas
# Processing Record 5 of Set 12 | zhigansk
# Processing Record 6 of Set 12 | barbar
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=barbar&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 7 of Set 12 | conceicao do araguaia
# Processing Record 8 of Set 12 | muros
# Processing Record 9 of Set 12 | acarau
# Processing Record 10 of Set 12 | el retorno
# Processing Record 11 of Set 12 | san angelo
# Processing Record 12 of Set 12 | gorontalo
# Processing Record 13 of Set 12 | luba
# Processing Record 14 of Set 12 | riachao das neves
# Processing Record 15 of Set 12 | gourcy
# Processing Record 16 of Set 12 | khomeyn
# Processing Record 17 of Set 12 | sohag
# Processing Record 18 of Set 12 | aklavik
# Processing Record 19 of Set 12 | santa isabel do rio negro
# Processing Record 20 of Set 12 | costa rica
# Processing Record 21 of Set 12 | shahumyan
# Processing Record 22 of Set 12 | katsuura
# Processing Record 23 of Set 12 | pevek
# Processing Record 24 of Set 12 | luang prabang
# Processing Record 25 of Set 12 | iskateley
# Processing Record 26 of Set 12 | ponta delgada
# Processing Record 27 of Set 12 | jiexiu
# Processing Record 28 of Set 12 | mahanoro
# Processing Record 29 of Set 12 | meulaboh
# Processing Record 30 of Set 12 | ust-nera
# Processing Record 31 of Set 12 | pierre
# Processing Record 32 of Set 12 | cottonwood
# Processing Record 33 of Set 12 | ballina
# Processing Record 34 of Set 12 | suifenhe
# Processing Record 35 of Set 12 | kemin
# Processing Record 36 of Set 12 | kadykchan
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=kadykchan&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 37 of Set 12 | xunchang
# Processing Record 38 of Set 12 | tondano
# Processing Record 39 of Set 12 | mandalgovi
# Processing Record 40 of Set 12 | of
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=of&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 41 of Set 12 | la libertad
# Processing Record 42 of Set 12 | fereydun kenar
# Processing Record 43 of Set 12 | chupa
# Processing Record 44 of Set 12 | nouadhibou
# Processing Record 45 of Set 12 | hofn
# Processing Record 46 of Set 12 | guanica
# Processing Record 47 of Set 12 | kasongo-lunda
# Processing Record 48 of Set 12 | aswan
# Processing Record 49 of Set 12 | iringa
# Processing Record 0 of Set 13 | tawkar
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=tawkar&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 1 of Set 13 | yatou
# Processing Record 2 of Set 13 | batagay-alyta
# Processing Record 3 of Set 13 | bur gabo
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=bur gabo&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 4 of Set 13 | praia da vitoria
# Processing Record 5 of Set 13 | tuy hoa
# Processing Record 6 of Set 13 | kavieng
# Processing Record 7 of Set 13 | santa maria da vitoria
# Processing Record 8 of Set 13 | mahajanga
# Processing Record 9 of Set 13 | londiani
# Processing Record 10 of Set 13 | grand bank
# Processing Record 11 of Set 13 | felidhoo
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=felidhoo&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 12 of Set 13 | boden
# Processing Record 13 of Set 13 | monchegorsk
# Processing Record 14 of Set 13 | banda aceh
# Processing Record 15 of Set 13 | rawannawi
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=rawannawi&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 16 of Set 13 | olafsvik
# Processing Record 17 of Set 13 | mushie
# Processing Record 18 of Set 13 | melo
# Processing Record 19 of Set 13 | pampas
# Processing Record 20 of Set 13 | lozovik
# Processing Record 21 of Set 13 | san pedro
# Processing Record 22 of Set 13 | grootfontein
# Processing Record 23 of Set 13 | maningrida
# Processing Record 24 of Set 13 | lamar
# Processing Record 25 of Set 13 | eldikan
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=eldikan&appid=a626b7a56ba247111d8206a91e0681fd&units=metric
# Processing Record 26 of Set 13 | dunedin
# Processing Record 27 of Set 13 | hasaki
# Processing Record 28 of Set 13 | wasilla
# Processing Record 29 of Set 13 | coihaique
# Processing Record 30 of Set 13 | palmer
# Processing Record 31 of Set 13 | bodden town
# Processing Record 32 of Set 13 | salalah
# Processing Record 33 of Set 13 | sakata
# Processing Record 34 of Set 13 | somcuta mare
# Processing Record 35 of Set 13 | layou
# Processing Record 36 of Set 13 | kahramanmaras
# Processing Record 37 of Set 13 | bodo
# Processing Record 38 of Set 13 | soloneshnoye
# Processing Record 39 of Set 13 | saint-georges
# Processing Record 40 of Set 13 | bubaque
# Processing Record 41 of Set 13 | pedro ii
# Processing Record 42 of Set 13 | daloa
# Processing Record 43 of Set 13 | nuqui
# Processing Record 44 of Set 13 | itacare
# Processing Record 45 of Set 13 | yacuiba
# Processing Record 46 of Set 13 | grande prairie
# Processing Record 47 of Set 13 | maturin
# Processing Record 48 of Set 13 | strunino
# Processing Record 49 of Set 13 | camacha
# Processing Record 0 of Set 14 | ladario
# Processing Record 1 of Set 14 | mokhsogollokh
# Processing Record 2 of Set 14 | elizabeth city
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          599
# Lat           599
# Lng           599
# Max Temp      599
# Humidity      599
# Cloudiness    599
# Wind Speed    599
# Country       599
# Date          599
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    mataura -46.1927  168.8643     14.62        80         100        2.31
# 1  bonavista  48.6499  -53.1147      1.15        98         100       10.73
# 2  mamedkala  42.1677   48.1199      1.59        80          49        2.43
# 3  mahebourg -20.4081   57.7000     26.25        78          75        5.14
# 4   calabozo   8.9242  -67.4293     35.81        25           9        2.02
#
#   Country        Date
# 0      NZ  1673898360
# 1      CA  1673898361
# 2      RU  1673898362
# 3      MU  1673898363
# 4      VE  1673898364

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          mataura -46.1927  168.8643     14.62        80         100
# 1        bonavista  48.6499  -53.1147      1.15        98         100
# 2        mamedkala  42.1677   48.1199      1.59        80          49
# 3        mahebourg -20.4081   57.7000     26.25        78          75
# 4         calabozo   8.9242  -67.4293     35.81        25           9
#
#          Wind Speed Country        Date
# City_ID
# 0              2.31      NZ  1673898360
# 1             10.73      CA  1673898361
# 2              2.43      RU  1673898362
# 3              5.14      MU  1673898363
# 4              2.02      VE  1673898364

# %%
year = pd.to_datetime(city_data_df['Date'],unit='s').dt.date[0]
print(year)
# Out:
# 2023-01-16

# %%
#city_data_df["Date"].describe()
# Date as a string
#iso_date = "2022-12-31 23:59:58"

# ISO format
#iso_format = "%Y-%m-%d %H:%M:%S"

# Convert the string into a datetime object
#datetime.strptime(iso_date, iso_format)

# %% [markdown]
# ### Create the Scatter Plots Requested
# Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat_plot = sns.scatterplot(data=city_data_df, x='Lat', y='Max Temp')
#latplot = plt.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)
#{city_data_df["Date"]}

# Incorporate the other graph properties
plt.title(f'City Max Latitude vs. Temperature {year}') #add on date to title
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. humidity
humidity_plot = sns.scatterplot(data=city_data_df, x='Lat', y='Humidity')
#latplot = plt.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)


# Incorporate the other graph properties
plt.title(f'City Max Latitude vs. Humidity {year} ')
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
cloudiness_plot = sns.scatterplot(data=city_data_df, x='Lat', y='Cloudiness')
#latplot = plt.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)


# Incorporate the other graph properties
plt.title(f'City Max Latitude vs. Cloudiness {year}')
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# Latitude vs. Wind Speed Plot

# %%
wind_speed_plot = sns.scatterplot(data=city_data_df, x='Lat', y='Wind Speed')
#latplot = plt.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)


# Incorporate the other graph properties
plt.title(f'City Max Latitude vs. Wind Speed {year}')
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
#linear regression on all datapoints

# Define a function to create Linear Regression plots
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
slope, intercept, r, p, se = linregress(x_values, y_values)
#print(slope,intercept, r, p, se )

regress_values = x_values * slope + intercept
#print(regress_values)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.query('Lat >= 0')

# Group the value according to a condition
#northern_hemi_df = northern_hemi_df.groupby('City')

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           bonavista  48.6499 -53.1147      1.15        98         100
# 2           mamedkala  42.1677  48.1199      1.59        80          49
# 4            calabozo   8.9242 -67.4293     35.81        25           9
# 5        ponta do sol  32.6667 -17.1000     16.35        59          14
# 6           ilulissat  69.2167 -51.1000    -19.99        65          40
#
#          Wind Speed Country        Date
# City_ID
# 1             10.73      CA  1673898361
# 2              2.43      RU  1673898362
# 4              2.02      VE  1673898364
# 5              3.48      PT  1673898365
# 6              7.72      GL  1673898366

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.query('Lat <= 0')


# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            mataura -46.1927  168.8643     14.62        80         100
# 3          mahebourg -20.4081   57.7000     26.25        78          75
# 7              bluff -46.6000  168.3333     15.32        76          19
# 8           antalaha -14.9003   50.2788     22.95        91         100
# 9        east london -33.0153   27.9116     24.03        91          69
#
#          Wind Speed Country        Date
# City_ID
# 0              2.31      NZ  1673898360
# 3              5.14      MU  1673898363
# 7              7.56      NZ  1673898367
# 8              2.68      MG  1673898367
# 9              3.14      ZA  1673898368

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
def lnregression(x,y, x_,y_, x_label,y_label):
    '''This function will calculate the linesar regression and the plot.'''
    # Linear regression on Northern Hemisphere
    x_values = x
    y_values= y
    slope, intercept, r, p, se = linregress(x_values, y_values)
    #print(slope,intercept, r, p, se )

    regress_values = x_values * slope + intercept
    #print(regress_values)

    line_eq = f'y = {str(round(slope,2))} x + {str(round(intercept,2))}'

    #return line_eq
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,(x_,y_),fontsize=15,color='red')
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()
    print(f'The r-value is: {r}.')

# %%
#plot
x = northern_hemi_df['Lat']
y = northern_hemi_df['Wind Speed']
x_label = 'Latitude >= 0'
y_label = 'Max Temperature'
#these are the coordinates for the annotation of the line
x_ = 20 
y_ = 15
lnregression(x, y, x_, y_, x_label, y_label)
# Out:
# The r-value is: 0.19929594767066167.

# %%
x = southern_hemi_df['Lat']
y = southern_hemi_df['Wind Speed']
x_label = 'Latitude <= 0'
y_label = 'Max Temperature'
x_ = -40
y_ = 14
lnregression(x, y, x_, y_, x_label, y_label)
# Out:
# The r-value is: -0.42760021249075386.

# %% [markdown]
# **Discussion about the linear relationship of Latitude and Temperature:**

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
#Northern Hemisphere 
x = northern_hemi_df['Lat']
y = northern_hemi_df['Humidity']
x_label = 'Latitude <= 0'
y_label = 'Max Temperature'
x_ = 45
y_ = 20
lnregression(x, y, x_, y_, x_label, y_label)
# Out:
# The r-value is: 0.44000053463794203.

# %%
plt.scatter(north_x_lat, north_y_humidity)
plt.plot(north_x_lat, north_regress_values, "r-")

#label plot
plt.xlabel('Latitude >= 0')
plt.ylabel('Humidity')
plt.annotate(line_eq,(20,15),fontsize=15,color='red')

#r-Value

# %%
#Southern Hemisphere
south_y_humidity = southern_hemi_df['Humidity']

# %%
plt.scatter(south_x_lat,south_y_humidity)
plt.plot(south_x_lat, south_regress_values, "r-")

#label plot
plt.xlabel('Latitude <= 0')
plt.ylabel('Max Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color='red')

#r-Value

# %% [markdown]
# **Discussion about the linear relationship of Latitude and Humidity:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
#Southern Hemisphere

# %%
plt.scatter(south_x,south_y)
plt.plot(south_x, south_regress_values, "r-")

#label plot
plt.xlabel('Latitude <= 0')
plt.ylabel('Max Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color='red')

# %% [markdown]
# **Discussion about the linear relationship of Latitude and Cloudiness:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship of Wind Speed and Latitude:** YOUR RESPONSE HERE
